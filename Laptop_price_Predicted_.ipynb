# %% [markdown]
# <a href="https://colab.research.google.com/github/G736saini/Laptop-price-Predicted-/blob/main/Laptop_price_Predicted_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
pr = pd.read_csv("/content/laptops.csv")
pr
# Out:
#     CompanyName        TypeOfLaptop     Inches  \
# 0           MSI     Business Laptop  17.040680
# 1         Chuwi  2 in 1 Convertible  16.542395
# 2            hp         WorkStation  17.295294
# 3           MSI  2 in 1 Convertible  11.526203
# 4     Microsoft              Gaming  12.649634
# ..          ...                 ...        ...
# 995          hp              Gaming  16.242566
# 996   Microsoft         WorkStation  17.450809
# 997      lenevo            NoteBook  13.761288
# 998        Asus           UltraBook  11.038000
# 999        Dell            NoteBook  11.005842
#
#                        ScreenResolution                             Cpu   Ram  \
# 0    IPS Panel Retina Display 2560x1600                   Intel Core i7  12GB
# 1                               Full HD                   Intel Core i5  12GB
# 2                               Full HD            Intel Xeon E3-1505M    8GB
# 3                                    2K                   Intel Core i7  16GB
# ...

# %%
pr.shape
# Out:
# (1000, 11)

# %%
pr.describe
# Out:
# <bound method NDFrame.describe of     CompanyName        TypeOfLaptop     Inches  \
# 0           MSI     Business Laptop  17.040680
# 1         Chuwi  2 in 1 Convertible  16.542395
# 2            hp         WorkStation  17.295294
# 3           MSI  2 in 1 Convertible  11.526203
# 4     Microsoft              Gaming  12.649634
# ..          ...                 ...        ...
# 995          hp              Gaming  16.242566
# 996   Microsoft         WorkStation  17.450809
# 997      lenevo            NoteBook  13.761288
# 998        Asus           UltraBook  11.038000
# 999        Dell            NoteBook  11.005842
#
#                        ScreenResolution                             Cpu   Ram  \
# 0    IPS Panel Retina Display 2560x1600                   Intel Core i7  12GB
# 1                               Full HD                   Intel Core i5  12GB
# 2                               Full HD            Intel Xeon E3-1505M    8GB
# ...

# %%
pr.isnull().sum()
# Out:
# CompanyName         0
# TypeOfLaptop        0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
pr.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CompanyName       1000 non-null   object
#  1   TypeOfLaptop      1000 non-null   object
#  2   Inches            1000 non-null   float64
#  3   ScreenResolution  1000 non-null   object
#  4   Cpu               1000 non-null   object
#  5   Ram               1000 non-null   object
#  6   Memory            1000 non-null   object
#  7   Gpu               1000 non-null   object
#  8   OpSys             1000 non-null   object
#  9   Weight            1000 non-null   float64
#  10  Price             1000 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 86.1+ KB

# %%
pr['Ram'] = pr['Ram'].str.replace('GB','')
pr['Ram'] = pr['Ram'].astype('int32')

# %%
pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CompanyName       1000 non-null   object
#  1   TypeOfLaptop      1000 non-null   object
#  2   Inches            1000 non-null   float64
#  3   ScreenResolution  1000 non-null   object
#  4   Cpu               1000 non-null   object
#  5   Ram               1000 non-null   int32
#  6   Memory            1000 non-null   object
#  7   Gpu               1000 non-null   object
#  8   OpSys             1000 non-null   object
#  9   Weight            1000 non-null   float64
#  10  Price             1000 non-null   float64
# dtypes: float64(3), int32(1), object(7)
# memory usage: 82.2+ KB

# %%
pr['CompanyName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='CompanyName'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr_matrix = ['Inches', 'Ram', 'Weight', 'Price']

sns.heatmap(pr[corr_matrix].corr(), cmap ='viridis', annot = True)
plt.show()

# %%
pr['TypeOfLaptop'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeOfLaptop'>

# %%
pr['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# 2K                                           181
# 4K                                           179
# IPS Panel Full HD / Touchscreen 1920x1080    176
# Full HD                                      162
# HD 1920x1080                                 160
# IPS Panel Retina Display 2560x1600           142
# Name: count, dtype: int64

# %%
pr['Ips'] = pr['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
pr.head()
# Out:
#   CompanyName        TypeOfLaptop     Inches  \
# 0         MSI     Business Laptop  17.040680
# 1       Chuwi  2 in 1 Convertible  16.542395
# 2          hp         WorkStation  17.295294
# 3         MSI  2 in 1 Convertible  11.526203
# 4   Microsoft              Gaming  12.649634
#
#                      ScreenResolution                   Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600         Intel Core i7   12
# 1                             Full HD         Intel Core i5   12
# 2                             Full HD  Intel Xeon E3-1505M     8
# 3                                  2K         Intel Core i7   16
# 4                             Full HD         Intel Core i5    8
#
#            Memory                     Gpu       OpSys    Weight         Price  \
# 0       512GB SSD  Intel Iris Xe Graphics       Linux  2.064834  35844.099371
# 1  128GB PCIe SSD  Intel Iris Xe Graphics       No OS  4.060656  37019.059051
# ...

# %%
pr['Touchscreen'] = pr['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
pr.head()
# Out:
#   CompanyName        TypeOfLaptop     Inches  \
# 0         MSI     Business Laptop  17.040680
# 1       Chuwi  2 in 1 Convertible  16.542395
# 2          hp         WorkStation  17.295294
# 3         MSI  2 in 1 Convertible  11.526203
# 4   Microsoft              Gaming  12.649634
#
#                      ScreenResolution                   Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600         Intel Core i7   12
# 1                             Full HD         Intel Core i5   12
# 2                             Full HD  Intel Xeon E3-1505M     8
# 3                                  2K         Intel Core i7   16
# 4                             Full HD         Intel Core i5    8
#
#            Memory                     Gpu       OpSys    Weight         Price  \
# 0       512GB SSD  Intel Iris Xe Graphics       Linux  2.064834  35844.099371
# 1  128GB PCIe SSD  Intel Iris Xe Graphics       No OS  4.060656  37019.059051
# ...

# %%
pr['x_res'] = pr['ScreenResolution'].str.split('x',n=1,expand=True)[0]
pr['y_res'] = pr['ScreenResolution'].str.split('x',n=1,expand=True)[1]

# %%
pr.head()
# Out:
#   CompanyName        TypeOfLaptop     Inches  \
# 0         MSI     Business Laptop  17.040680
# 1       Chuwi  2 in 1 Convertible  16.542395
# 2          hp         WorkStation  17.295294
# 3         MSI  2 in 1 Convertible  11.526203
# 4   Microsoft              Gaming  12.649634
#
#                      ScreenResolution                   Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600         Intel Core i7   12
# 1                             Full HD         Intel Core i5   12
# 2                             Full HD  Intel Xeon E3-1505M     8
# 3                                  2K         Intel Core i7   16
# 4                             Full HD         Intel Core i5    8
#
#            Memory                     Gpu       OpSys    Weight         Price  \
# 0       512GB SSD  Intel Iris Xe Graphics       Linux  2.064834  35844.099371
# 1  128GB PCIe SSD  Intel Iris Xe Graphics       No OS  4.060656  37019.059051
# ...

# %%
pr['x_res'] = pr['x_res'].str.replace(',', '').str.findall(r'(\d+\.?\d+)').apply(lambda x: x[0] if x else np.nan)

# %%
pr.head()
# Out:
#   CompanyName        TypeOfLaptop     Inches  \
# 0         MSI     Business Laptop  17.040680
# 1       Chuwi  2 in 1 Convertible  16.542395
# 2          hp         WorkStation  17.295294
# 3         MSI  2 in 1 Convertible  11.526203
# 4   Microsoft              Gaming  12.649634
#
#                      ScreenResolution                   Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600         Intel Core i7   12
# 1                             Full HD         Intel Core i5   12
# 2                             Full HD  Intel Xeon E3-1505M     8
# 3                                  2K         Intel Core i7   16
# 4                             Full HD         Intel Core i5    8
#
#            Memory                     Gpu       OpSys    Weight         Price  \
# 0       512GB SSD  Intel Iris Xe Graphics       Linux  2.064834  35844.099371
# 1  128GB PCIe SSD  Intel Iris Xe Graphics       No OS  4.060656  37019.059051
# ...

# %%
pr.pop('x')
# Out:
# 0      [IPS Panel Retina Display 2560, 1600]
# 1                                  [Full HD]
# 2                                  [Full HD]
# 3                                       [2K]
# 4                                  [Full HD]
#                        ...
# 995                         [HD 1920, 1080 ]
# 996                                     [4K]
# 997                         [HD 1920, 1080 ]
# 998    [IPS Panel Retina Display 2560, 1600]
# 999                                [Full HD]
# Name: x, Length: 1000, dtype: object

# %%
pr.head()
# Out:
#   CompanyName        TypeOfLaptop     Inches  \
# 0         MSI     Business Laptop  17.040680
# 1       Chuwi  2 in 1 Convertible  16.542395
# 2          hp         WorkStation  17.295294
# 3         MSI  2 in 1 Convertible  11.526203
# 4   Microsoft              Gaming  12.649634
#
#                      ScreenResolution                   Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600         Intel Core i7   12
# 1                             Full HD         Intel Core i5   12
# 2                             Full HD  Intel Xeon E3-1505M     8
# 3                                  2K         Intel Core i7   16
# 4                             Full HD         Intel Core i5    8
#
#            Memory                     Gpu       OpSys    Weight         Price  \
# 0       512GB SSD  Intel Iris Xe Graphics       Linux  2.064834  35844.099371
# 1  128GB PCIe SSD  Intel Iris Xe Graphics       No OS  4.060656  37019.059051
# ...

# %%
pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CompanyName       1000 non-null   object
#  1   TypeOfLaptop      1000 non-null   object
#  2   Inches            1000 non-null   float64
#  3   ScreenResolution  1000 non-null   object
#  4   Cpu               1000 non-null   object
#  5   Ram               1000 non-null   int32
#  6   Memory            1000 non-null   object
#  7   Gpu               1000 non-null   object
#  8   OpSys             1000 non-null   object
#  9   Weight            1000 non-null   float64
#  10  Price             1000 non-null   float64
#  11  Ips               1000 non-null   int64
#  12  Touchscreen       1000 non-null   int64
#  13  x_res             478 non-null    object
#  14  y_res             478 non-null    object
# dtypes: float64(3), int32(1), int64(2), object(9)
# ...

# %%
pr['x_res'] = pr['x_res'].astype('Int64')

# %%
pr['y_res'] = pr['y_res'].astype('Int64')

# %%
pr['ppi']=(((pr['x_res']**2) + (pr['y_res']**2))**0.5/pr['Inches']).astype('float')

# %%
pr.corr(numeric_only= True)['Price']
# Out:
# Inches        -0.012535
# Ram            0.063615
# Weight        -0.024256
# Price          1.000000
# Ips           -0.007610
# Touchscreen    0.004964
# x_res         -0.009008
# y_res         -0.009008
# ppi           -0.016865
# Name: Price, dtype: float64

# %%
pr.drop(columns=['ScreenResolution'],inplace=True)

# %%
pr.head()
# Out:
#   CompanyName        TypeOfLaptop     Inches                   Cpu  Ram  \
# 0         MSI     Business Laptop  17.040680         Intel Core i7   12
# 1       Chuwi  2 in 1 Convertible  16.542395         Intel Core i5   12
# 2          hp         WorkStation  17.295294  Intel Xeon E3-1505M     8
# 3         MSI  2 in 1 Convertible  11.526203         Intel Core i7   16
# 4   Microsoft              Gaming  12.649634         Intel Core i5    8
#
#            Memory                     Gpu       OpSys    Weight         Price  \
# 0       512GB SSD  Intel Iris Xe Graphics       Linux  2.064834  35844.099371
# 1  128GB PCIe SSD  Intel Iris Xe Graphics       No OS  4.060656  37019.059051
# 2         1TB HDD  Intel Iris Xe Graphics       Linux  2.901689  33329.360341
# 3  512GB NVMe SSD  Intel Iris Xe Graphics  Windows 10  2.914843  68631.102486
# 4       512GB SSD     AMD Radeon RX 5600M  Windows 10  4.341995  33842.479566
#
#    Ips  Touchscreen  x_res  y_res         ppi
# ...

# %%
pr.drop(columns=['Inches','x_res','y_res'],inplace=True)

# %%
pr.head()
# Out:
#   CompanyName        TypeOfLaptop                   Cpu  Ram          Memory  \
# 0         MSI     Business Laptop         Intel Core i7   12       512GB SSD
# 1       Chuwi  2 in 1 Convertible         Intel Core i5   12  128GB PCIe SSD
# 2          hp         WorkStation  Intel Xeon E3-1505M     8         1TB HDD
# 3         MSI  2 in 1 Convertible         Intel Core i7   16  512GB NVMe SSD
# 4   Microsoft              Gaming         Intel Core i5    8       512GB SSD
#
#                       Gpu       OpSys    Weight         Price  Ips  \
# 0  Intel Iris Xe Graphics       Linux  2.064834  35844.099371    1
# 1  Intel Iris Xe Graphics       No OS  4.060656  37019.059051    0
# 2  Intel Iris Xe Graphics       Linux  2.901689  33329.360341    0
# 3  Intel Iris Xe Graphics  Windows 10  2.914843  68631.102486    0
# 4     AMD Radeon RX 5600M  Windows 10  4.341995  33842.479566    0
#
#    Touchscreen         ppi
# 0            0  177.156896
# 1            0         NaN
# ...

# %%
pr['Cpu'].value_counts()
# Out:
# Cpu
# Intel Xeon E3-1505M               114
# Intel Atom x5-Z8550               111
# Intel Core i5                     105
# Intel Pentium Quad Core N4200     101
# Intel Celeron Dual Core 3855U      98
# Intel Core i7                      96
# Intel Core i9                      95
# AMD Ryzen 5                        94
# AMD Ryzen 7                        94
# AMD A9-Series 9420                 92
# Name: count, dtype: int64

# %%
pr['cpu name']=pr['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
pr.head()
# Out:
#   CompanyName        TypeOfLaptop                   Cpu  Ram          Memory  \
# 0         MSI     Business Laptop         Intel Core i7   12       512GB SSD
# 1       Chuwi  2 in 1 Convertible         Intel Core i5   12  128GB PCIe SSD
# 2          hp         WorkStation  Intel Xeon E3-1505M     8         1TB HDD
# 3         MSI  2 in 1 Convertible         Intel Core i7   16  512GB NVMe SSD
# 4   Microsoft              Gaming         Intel Core i5    8       512GB SSD
#
#                       Gpu       OpSys    Weight         Price  Ips  \
# 0  Intel Iris Xe Graphics       Linux  2.064834  35844.099371    1
# 1  Intel Iris Xe Graphics       No OS  4.060656  37019.059051    0
# 2  Intel Iris Xe Graphics       Linux  2.901689  33329.360341    0
# 3  Intel Iris Xe Graphics  Windows 10  2.914843  68631.102486    0
# 4     AMD Radeon RX 5600M  Windows 10  4.341995  33842.479566    0
#
#    Touchscreen         ppi             cpu name
# 0            0  177.156896        Intel Core i7
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'

        else:
            return 'AMD Processor'

# %%
pr['Cpu brand'] = pr['cpu name'].apply(fetch_processor)

# %%
pr.head()
# Out:
#   CompanyName        TypeOfLaptop                   Cpu  Ram          Memory  \
# 0         MSI     Business Laptop         Intel Core i7   12       512GB SSD
# 1       Chuwi  2 in 1 Convertible         Intel Core i5   12  128GB PCIe SSD
# 2          hp         WorkStation  Intel Xeon E3-1505M     8         1TB HDD
# 3         MSI  2 in 1 Convertible         Intel Core i7   16  512GB NVMe SSD
# 4   Microsoft              Gaming         Intel Core i5    8       512GB SSD
#
#                       Gpu       OpSys    Weight         Price  Ips  \
# 0  Intel Iris Xe Graphics       Linux  2.064834  35844.099371    1
# 1  Intel Iris Xe Graphics       No OS  4.060656  37019.059051    0
# 2  Intel Iris Xe Graphics       Linux  2.901689  33329.360341    0
# 3  Intel Iris Xe Graphics  Windows 10  2.914843  68631.102486    0
# 4     AMD Radeon RX 5600M  Windows 10  4.341995  33842.479566    0
#
#    Touchscreen         ppi             cpu name              Cpu brand
# ...

# %%
pr.drop(columns=['Cpu','cpu name'],inplace=True)

# %%
pr.head()
# Out:
#   CompanyName        TypeOfLaptop  Ram          Memory  \
# 0         MSI     Business Laptop   12       512GB SSD
# 1       Chuwi  2 in 1 Convertible   12  128GB PCIe SSD
# 2          hp         WorkStation    8         1TB HDD
# 3         MSI  2 in 1 Convertible   16  512GB NVMe SSD
# 4   Microsoft              Gaming    8       512GB SSD
#
#                       Gpu       OpSys    Weight         Price  Ips  \
# 0  Intel Iris Xe Graphics       Linux  2.064834  35844.099371    1
# 1  Intel Iris Xe Graphics       No OS  4.060656  37019.059051    0
# 2  Intel Iris Xe Graphics       Linux  2.901689  33329.360341    0
# 3  Intel Iris Xe Graphics  Windows 10  2.914843  68631.102486    0
# 4     AMD Radeon RX 5600M  Windows 10  4.341995  33842.479566    0
#
#    Touchscreen         ppi              Cpu brand
# 0            0  177.156896          Intel Core i7
# 1            0         NaN          Intel Core i5
# 2            0         NaN  Other Intel Processor
# ...

# %%
pr['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
pr['Memory'].value_counts()
# Out:
# Memory
# 1TB HDD                105
# 2TB SATA SSD            63
# 1TB SSHD                61
# 4TB HDD                 60
# 512GB eMMC              59
# 128GB PCIe SSD          58
# 1TB NVMe SSD            55
# 256GB PCIe SSD          55
# 512GB NVMe SSD          54
# 512GB SSD               51
# 2TB HDD                 50
# 256GB SSD               50
# 1TB Fusion Drive        50
# 2TB NVMe SSD            49
# 256GB Flash Storage     46
# 256GB eMMC              45
# 6TB HDD                 45
# 128GB SSD               44
# Name: count, dtype: int64

# %%
pr['Gpu'].value_counts()
# Out:
# Gpu
# NVIDIA GeForce GTX 1650    348
# AMD Radeon RX 5600M        339
# Intel Iris Xe Graphics     313
# Name: count, dtype: int64

# %%
pr['Gpu brand']= pr['Gpu'].apply(lambda x:x.split()[0])

# %%
pr.head()
# Out:
#   CompanyName        TypeOfLaptop  Ram          Memory  \
# 0         MSI     Business Laptop   12       512GB SSD
# 1       Chuwi  2 in 1 Convertible   12  128GB PCIe SSD
# 2          hp         WorkStation    8         1TB HDD
# 3         MSI  2 in 1 Convertible   16  512GB NVMe SSD
# 4   Microsoft              Gaming    8       512GB SSD
#
#                       Gpu       OpSys    Weight         Price  Ips  \
# 0  Intel Iris Xe Graphics       Linux  2.064834  35844.099371    1
# 1  Intel Iris Xe Graphics       No OS  4.060656  37019.059051    0
# 2  Intel Iris Xe Graphics       Linux  2.901689  33329.360341    0
# 3  Intel Iris Xe Graphics  Windows 10  2.914843  68631.102486    0
# 4     AMD Radeon RX 5600M  Windows 10  4.341995  33842.479566    0
#
#    Touchscreen         ppi              Cpu brand Gpu brand
# 0            0  177.156896          Intel Core i7     Intel
# 1            0         NaN          Intel Core i5     Intel
# ...

# %%
pr['Gpu brand'].value_counts()
# Out:
# Gpu brand
# NVIDIA    348
# AMD       339
# Intel     313
# Name: count, dtype: int64

# %%
pr.drop(columns=['Gpu'],inplace=True)

# %%
pr.head()
# Out:
#   CompanyName        TypeOfLaptop  Ram          Memory       OpSys    Weight  \
# 0         MSI     Business Laptop   12       512GB SSD       Linux  2.064834
# 1       Chuwi  2 in 1 Convertible   12  128GB PCIe SSD       No OS  4.060656
# 2          hp         WorkStation    8         1TB HDD       Linux  2.901689
# 3         MSI  2 in 1 Convertible   16  512GB NVMe SSD  Windows 10  2.914843
# 4   Microsoft              Gaming    8       512GB SSD  Windows 10  4.341995
#
#           Price  Ips  Touchscreen         ppi              Cpu brand Gpu brand
# 0  35844.099371    1            0  177.156896          Intel Core i7     Intel
# 1  37019.059051    0            0         NaN          Intel Core i5     Intel
# 2  33329.360341    0            0         NaN  Other Intel Processor     Intel
# 3  68631.102486    0            0         NaN          Intel Core i7     Intel
# 4  33842.479566    0            0         NaN          Intel Core i5       AMD

# %%
pr['OpSys'].value_counts()
# Out:
# OpSys
# No OS         224
# macOS         219
# Windows 10    194
# Linux         187
# Windows 11    176
# Name: count, dtype: int64

# %%
def clean_os(text):
    if text == 'Windows 10' or text == 'Windows 7' or text == 'Windows 10 S':
        return 'Windows'
    elif text == 'macOS' or text == 'Mac OS X':
        return 'Mac'
    else:
        return text

# %%
pr['os'] = pr['OpSys'].apply(clean_os)

# %%
pr.head()
# Out:
#   CompanyName        TypeOfLaptop  Ram          Memory       OpSys    Weight  \
# 0         MSI     Business Laptop   12       512GB SSD       Linux  2.064834
# 1       Chuwi  2 in 1 Convertible   12  128GB PCIe SSD       No OS  4.060656
# 2          hp         WorkStation    8         1TB HDD       Linux  2.901689
# 3         MSI  2 in 1 Convertible   16  512GB NVMe SSD  Windows 10  2.914843
# 4   Microsoft              Gaming    8       512GB SSD  Windows 10  4.341995
#
#           Price  Ips  Touchscreen         ppi              Cpu brand  \
# 0  35844.099371    1            0  177.156896          Intel Core i7
# 1  37019.059051    0            0         NaN          Intel Core i5
# 2  33329.360341    0            0         NaN  Other Intel Processor
# 3  68631.102486    0            0         NaN          Intel Core i7
# 4  33842.479566    0            0         NaN          Intel Core i5
#
#   Gpu brand       os
# 0     Intel    Linux
# 1     Intel    No OS
# ...

# %%
pr.drop(columns=['OpSys'],inplace=True)

# %%
sns.heatmap(pr.corr(numeric_only= True))
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(pr.drop(columns=['Price']),pr['Price'],test_size=0.25,random_state=2)
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.metrics import mean_squared_error, r2_score

# %%
x_train
# Out:
#     CompanyName     TypeOfLaptop  Ram            Memory    Weight  Ips  \
# 673        Asus           Gaming   16         512GB SSD  2.459829    0
# 107        Acer      WorkStation   16         128GB SSD  3.396037    1
# 898        Dell      WorkStation   16           2TB HDD  3.452190    0
# 441   Microsoft         NoteBook    8           6TB HDD  2.543689    0
# 439        Dell      WorkStation   12           2TB HDD  4.064641    0
# ..          ...              ...  ...               ...       ...  ...
# 534         MSI      WorkStation   16      2TB SATA SSD  3.730538    1
# 584          hp        UltraBook    4           1TB HDD  4.630746    1
# 493       Chuwi        UltraBook   16          1TB SSHD  3.815879    1
# 527        Acer  Business Laptop   12  1TB Fusion Drive  4.592649    1
# 168         MSI         NoteBook    8         256GB SSD  3.986897    1
#
#      Touchscreen         ppi              Cpu brand Gpu brand          os
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor

# %%
pr.head(1)
# Out:
#   CompanyName     TypeOfLaptop  Ram     Memory    Weight         Price  Ips  \
# 0         MSI  Business Laptop   12  512GB SSD  2.064834  35844.099371    1
#
#    Touchscreen         ppi      Cpu brand Gpu brand     os
# 0            0  177.156896  Intel Core i7     Intel  Linux

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer # Import SimpleImputer

# Split data (this part is already done in the notebook but included for completeness)
x_train, x_test, y_train, y_test = train_test_split(pr.drop(columns=['Price']), pr['Price'], test_size=0.25, random_state=2)

# Define the column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0, 1, 3, 8, 9, 10]) # Categorical features indices
], remainder='passthrough')

# Add an imputer step to handle missing values
step2 = SimpleImputer(strategy='mean') # Use mean imputation for numerical features

# Define the linear regression model
step3 = LinearRegression()

# Create the pipeline with the imputer step
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2), # Imputation step
    ('step3', step3)  # Linear Regression step
])

# Fit the pipeline
pipe.fit(x_train, y_train)

# Make predictions and evaluate
y_pred = pipe.predict(x_test)
print('R2 score', r2_score(y_test, y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score -0.025363500155660246
# RMSE 13630.442754369717

# %%
np.exp(0.21)
# Out:
# np.float64(1.2336780599567432)

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0, 1, 3, 8, 9, 10]) # Categorical features indices
], remainder='passthrough')

# Add an imputer step to handle missing values
step2 = SimpleImputer(strategy='mean') # Use mean imputation for numerical features

# Define the linear regression model
step3 = Lasso(alpha=0.001)

# Create the pipeline with the imputer step
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2), # Imputation step
    ('step3', step3)  # Linear Regression step
])

# Fit the pipeline
pipe.fit(x_train, y_train)

# Make predictions and evaluate
y_pred = pipe.predict(x_test)
print('R2 score', r2_score(y_test, y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score -0.02536256657275393
# RMSE 13630.43654917943

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0, 1, 3, 8, 9, 10]) # Categorical features indices
], remainder='passthrough')

# Add an imputer step to handle missing values
step2 = SimpleImputer(strategy='mean') # Use mean imputation for numerical features

# Define the linear regression model
step3 =Ridge(alpha=10)

# Create the pipeline with the imputer step
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2), # Imputation step
    ('step3', step3)  # Linear Regression step
])

# Fit the pipeline
pipe.fit(x_train, y_train)

# Make predictions and evaluate
y_pred = pipe.predict(x_test)
print('R2 score', r2_score(y_test, y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score -0.004031331993312515
# RMSE 13487.910301018499

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0, 1, 3, 8, 9, 10]) # Categorical features indices
], remainder='passthrough')

# Add an imputer step to handle missing values
step2 = SimpleImputer(strategy='mean') # Use mean imputation for numerical features

# Define the linear regression model
step3 = KNeighborsRegressor(n_neighbors=3)

# Create the pipeline with the imputer step
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2), # Imputation step
    ('step3', step3)  # Linear Regression step
])

# Fit the pipeline
pipe.fit(x_train, y_train)

# Make predictions and evaluate
y_pred = pipe.predict(x_test)
print('R2 score', r2_score(y_test, y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score -0.24986119839060872
# RMSE 15048.802033353384

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0, 1, 3, 8, 9, 10]) # Categorical features indices
], remainder='passthrough')

# Add an imputer step to handle missing values
step2 = SimpleImputer(strategy='mean') # Use mean imputation for numerical features

# Define the linear regression model
step3 = DecisionTreeRegressor(max_depth=8)

# Create the pipeline with the imputer step
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2), # Imputation step
    ('step3', step3)  # Linear Regression step
])

# Fit the pipeline
pipe.fit(x_train, y_train)

# Make predictions and evaluate
y_pred = pipe.predict(x_test)
print('R2 score', r2_score(y_test, y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score 0.03357675413456851
# RMSE 13232.890539569122

# %%
from sklearn.svm import SVR
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0, 1, 3, 8, 9, 10]) # Categorical features indices
], remainder='passthrough')

# Add an imputer step to handle missing values
step2 = SimpleImputer(strategy='mean') # Use mean imputation for numerical features

# Define the linear regression model
step3 = SVR(kernel = 'rbf',C = 10000 ,epsilon = 0.1)

# Create the pipeline with the imputer step
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2), # Imputation step
    ('step3', step3)  # Linear Regression step
])

# Fit the pipeline
pipe.fit(x_train, y_train)

# Make predictions and evaluate
y_pred = pipe.predict(x_test)
print('R2 score', r2_score(y_test, y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score -0.011288585337934087
# RMSE 13536.568611816361

# %%
from sklearn.svm import SVR
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0, 1, 3, 8, 9, 10]) # Categorical features indices
], remainder='passthrough')

# Add an imputer step to handle missing values
step2 = SimpleImputer(strategy='mean') # Use mean imputation for numerical features

# Define the linear regression model
step3 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

# Create the pipeline with the imputer step
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2), # Imputation step
    ('step3', step3)  # Linear Regression step
])

# Fit the pipeline
pipe.fit(x_train, y_train)

# Make predictions and evaluate
y_pred = pipe.predict(x_test)
print('R2 score', r2_score(y_test, y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score 0.14074092909809388
# RMSE 12477.658606893037

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
pickle.dump(pr,open('pr.pkl','wb'))

# %%
from sklearn.ensemble import AdaBoostRegressor
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0, 1, 3, 8, 9, 10]) # Categorical features indices
], remainder='passthrough')

# Add an imputer step to handle missing values
step2 = SimpleImputer(strategy='mean') # Use mean imputation for numerical features

# Define the linear regression model
step3 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

# Create the pipeline with the imputer step
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2), # Imputation step
    ('step3', step3)  # Linear Regression step
])

# Fit the pipeline
pipe.fit(x_train, y_train)

# Make predictions and evaluate
y_pred = pipe.predict(x_test)
print('R2 score', r2_score(y_test, y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score 0.2209568762537476
# RMSE 11880.966888867386

# %%
from sklearn.ensemble import GradientBoostingRegressor
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0, 1, 3, 8, 9, 10]) # Categorical features indices
], remainder='passthrough')

# Add an imputer step to handle missing values
step2 = SimpleImputer(strategy='mean') # Use mean imputation for numerical features

# Define the linear regression model
step3 = GradientBoostingRegressor(n_estimators=500)

# Create the pipeline with the imputer step
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2), # Imputation step
    ('step3', step3)  # Linear Regression step
])

# Fit the pipeline
pipe.fit(x_train, y_train)

# Make predictions and evaluate
y_pred = pipe.predict(x_test)
print('R2 score', r2_score(y_test, y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score 0.009709213779031
# RMSE 13395.298795198834

# %%
from sklearn.ensemble import AdaBoostRegressor
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0, 1, 3, 8, 9, 10]) # Categorical features indices
], remainder='passthrough')

# Add an imputer step to handle missing values
step2 = SimpleImputer(strategy='mean') # Use mean imputation for numerical features

# Define the linear regression model
step3 = XGBRegressor(n_estimators=45,learning_rate=0.5,max_depth = 5)

# Create the pipeline with the imputer step
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2), # Imputation step
    ('step3', step3)  # Linear Regression step
])

# Fit the pipeline
pipe.fit(x_train, y_train)

# Make predictions and evaluate
y_pred = pipe.predict(x_test)
print('R2 score', r2_score(y_test, y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score 0.035650062473268185
# RMSE 13218.688380706413

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
pickle.dump(pr,open('pr.pkl','wb'))
